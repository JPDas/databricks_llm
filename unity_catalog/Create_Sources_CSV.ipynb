# %%
# %pip install databricks-feature-engineering

# Restart Python kernel to ensure all dependencies are properly initialized
dbutils.library.restartPython()
# Out:
# Looking in indexes: [REDACTED]
# Collecting databricks-feature-engineering
#   Downloading http://node.host.local:8184/pypi/v1/packages/databricks-feature-engineering/0.16.1/databricks_feature_engineering-0.16.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: mlflow-skinny<4,>=2.16.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.8.1)
# Requirement already satisfied: pyyaml<7,>=6 in /databricks/python3/lib/python3.12/site-packages (from databricks-feature-engineering) (6.0.2)
# Requirement already satisfied: boto3<2,>=1.16.7 in /databricks/python3/lib/python3.12/site-packages (from databricks-feature-engineering) (1.40.45)
# Collecting dbl-tempo<1,>=0.1.26 (from databricks-feature-engineering)
#   Downloading http://node.host.local:8184/pypi/v1/packages/dbl-tempo/0.1.30/dbl_tempo-0.1.30-py3-none-any.whl.metadata (12 kB)
# Collecting azure-cosmos==4.3.1 (from databricks-feature-engineering)
#   Downloading http://node.host.local:8184/pypi/v1/packages/azure-cosmos/4.3.1/azure_cosmos-4.3.1-py3-none-any.whl.metadata (52 kB)
# Requirement already satisfied: numpy<3,>=1.19.2 in /databricks/python3/lib/python3.12/site-packages (from databricks-feature-engineering) (2.1.3)
# Requirement already satisfied: protobuf<7,>=5 in /databricks/python3/lib/python3.12/site-packages (from databricks-feature-engineering) (5.29.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-feature-engineering) (0.5.5)
# Collecting databricks-sdk<1,>=0.116.0 (from databricks-feature-engineering)
#   Downloading http://node.host.local:8184/pypi/v1/packages/databricks-sdk/0.133.0/databricks_sdk-0.133.0-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in /databricks/python3/lib/python3.12/site-packages (from azure-cosmos==4.3.1->databricks-feature-engineering) (1.37.0)
# Requirement already satisfied: botocore<1.41.0,>=1.40.45 in /databricks/python3/lib/python3.12/site-packages (from boto3<2,>=1.16.7->databricks-feature-engineering) (1.40.45)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /databricks/python3/lib/python3.12/site-packages (from boto3<2,>=1.16.7->databricks-feature-engineering) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /databricks/python3/lib/python3.12/site-packages (from boto3<2,>=1.16.7->databricks-feature-engineering) (0.14.0)
# Requirement already satisfied: requests<3,>=2.28.1 in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk<1,>=0.116.0->databricks-feature-engineering) (2.32.3)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk<1,>=0.116.0->databricks-feature-engineering) (2.47.0)
# Collecting protobuf<7,>=5 (from databricks-feature-engineering)
#   Downloading http://node.host.local:8184/pypi/v1/packages/protobuf/6.33.6/protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: urllib3<3,>=1.26 in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk<1,>=0.116.0->databricks-feature-engineering) (2.3.0)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.0.0)
# Requirement already satisfied: fastapi<1 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.128.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.39.1)
# Requirement already satisfied: packaging<26 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (24.2)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.10.6)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.2.1)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (4.12.2)
# Requirement already satisfied: uvicorn<1 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.40.0)
# Requirement already satisfied: azure-storage-file-datalake>12 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (12.22.0)
# Requirement already satisfied: google-cloud-storage>=1.30.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.7.0)
# Requirement already satisfied: databricks-agents<2.0,>=1.2.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.9.1)
# Requirement already satisfied: azure-storage-blob>=12.27.0 in /databricks/python3/lib/python3.12/site-packages (from azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (12.28.0)
# Requirement already satisfied: isodate>=0.6.1 in /databricks/python3/lib/python3.12/site-packages (from azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /databricks/python3/lib/python3.12/site-packages (from botocore<1.41.0,>=1.40.45->boto3<2,>=1.16.7->databricks-feature-engineering) (2.9.0.post0)
# Requirement already satisfied: dataclasses-json in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.6.7)
# Requirement already satisfied: googleapis-common-protos in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.65.0)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.2.3)
# Requirement already satisfied: jinja2>=3.0.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.1.6)
# Requirement already satisfied: tenacity>=8.5 in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (9.0.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.12.0)
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (4.67.1)
# Requirement already satisfied: whenever==0.7.3 in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.7.3)
# Requirement already satisfied: litellm==1.75.9 in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.75.9)
# Requirement already satisfied: aiohttp>=3.10 in /databricks/python3/lib/python3.12/site-packages (from litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.11.10)
# Requirement already satisfied: httpx>=0.23.0 in /databricks/python3/lib/python3.12/site-packages (from litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.28.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /databricks/python3/lib/python3.12/site-packages (from litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (4.23.0)
# Requirement already satisfied: openai>=1.99.5 in /databricks/python3/lib/python3.12/site-packages (from litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.14.0)
# Requirement already satisfied: tokenizers in /databricks/python3/lib/python3.12/site-packages (from litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.22.2)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /databricks/python3/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /databricks/python3/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (4.0.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.116.0->databricks-feature-engineering) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.116.0->databricks-feature-engineering) (4.9.1)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.8.0)
# Requirement already satisfied: zipp>=3.20 in /databricks/python3/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.21.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.28.1->databricks-sdk<1,>=0.116.0->databricks-feature-engineering) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.28.1->databricks-sdk<1,>=0.116.0->databricks-feature-engineering) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.28.1->databricks-sdk<1,>=0.116.0->databricks-feature-engineering) (2025.4.26)
# Requirement already satisfied: h11>=0.8 in /databricks/python3/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.16.0)
# Requirement already satisfied: cryptography>=2.1.4 in /databricks/python3/lib/python3.12/site-packages (from azure-storage-blob>=12.27.0->azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (44.0.1)
# Requirement already satisfied: langchain-openai in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.1.6)
# Requirement already satisfied: smmap<6,>=3.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (5.0.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /databricks/python3/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.27.0)
#   Downloading http://node.host.local:8184/pypi/v1/packages/protobuf/5.29.6/protobuf-5.29.6-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.12/site-packages (from jinja2>=3.0.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.116.0->databricks-feature-engineering) (0.4.8)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.45->boto3<2,>=1.16.7->databricks-feature-engineering) (1.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /databricks/python3/lib/python3.12/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (4.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /databricks/python3/lib/python3.12/site-packages (from tiktoken>=0.8.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2024.11.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /databricks/python3/lib/python3.12/site-packages (from dataclasses-json->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from dataclasses-json->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.9.0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /databricks/python3/lib/python3.12/site-packages (from pandas->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.18.0)
# Requirement already satisfied: sniffio>=1.1 in /databricks/python3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.12/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.27.0->azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.17.1)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.12/site-packages (from httpx>=0.23.0->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /databricks/python3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /databricks/python3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /databricks/python3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.22.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.99.5->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /databricks/python3/lib/python3.12/site-packages (from openai>=1.99.5->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.12.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.2 in /databricks/python3/lib/python3.12/site-packages (from langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.2.6)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /databricks/python3/lib/python3.12/site-packages (from tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.2.4)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.27.0->azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2.21)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (2023.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.2.0)
# Requirement already satisfied: shellingham in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.5.4)
# Requirement already satisfied: typer-slim in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.21.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /databricks/python3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /databricks/python3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.6.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /databricks/python3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /databricks/python3/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /databricks/python3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /databricks/python3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /databricks/python3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering) (0.23.0)
# Downloading http://node.host.local:8184/pypi/v1/packages/databricks-feature-engineering/0.16.1/databricks_feature_engineering-0.16.1-py3-none-any.whl (393 kB)
# Downloading http://node.host.local:8184/pypi/v1/packages/azure-cosmos/4.3.1/azure_cosmos-4.3.1-py3-none-any.whl (222 kB)
# Downloading http://node.host.local:8184/pypi/v1/packages/databricks-sdk/0.133.0/databricks_sdk-0.133.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 36.3 MB/s eta 0:00:00
# Downloading http://node.host.local:8184/pypi/v1/packages/dbl-tempo/0.1.30/dbl_tempo-0.1.30-py3-none-any.whl (41 kB)
# Downloading http://node.host.local:8184/pypi/v1/packages/protobuf/5.29.6/protobuf-5.29.6-cp38-abi3-manylinux2014_x86_64.whl (320 kB)
# Installing collected packages: protobuf, dbl-tempo, databricks-sdk, azure-cosmos, databricks-feature-engineering
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Not uninstalling protobuf at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-ec8ef93d-5b16-4c18-9b20-2a6db1ca40db
#     Can't uninstall 'protobuf'. No files were found to uninstall.
#   Attempting uninstall: databricks-sdk
#     Found existing installation: databricks-sdk 0.67.0
#     Not uninstalling databricks-sdk at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-ec8ef93d-5b16-4c18-9b20-2a6db1ca40db
#     Can't uninstall 'databricks-sdk'. No files were found to uninstall.
# Successfully installed azure-cosmos-4.3.1 databricks-feature-engineering-0.16.1 databricks-sdk-0.133.0 dbl-tempo-0.1.30 protobuf-5.29.6
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# ## Feature Tables Creation

# %%
# %run ../_config/Config_Unity_Catalog
# Out:
# Using catalog: demo
# Using schema: demo

# %% [markdown]
# ## Load CSV files

# %%
# Define the source location (GitHub raw content URL)
prefix = "https://github.com/JPDas/databricks_llm/tree/main/"

# This is the staging area for raw data before creating feature tables
path_volume = f"/Volumes/{catalog}/{schema}/raw_data/"

# List of CSV file names to download and process
l_csv_names = [
    "customers",        # Customer master data (demographics, contact info)
    "orders",           # Order transactions (order_id, date, status, total)
    "order_items",      # Line items for each order (product_id, quantity, price)
    "products",         # Product catalog (name, category, price, inventory)
    "shipping_zones"    # Shipping zones and rates by geography
]

# Download each CSV file from GitHub to the Unity Catalog volume
for csv_name in l_csv_names:
    # Construct source path
    source_path = f"{prefix}data/csv/{csv_name}.csv"
    
    # Construct destination path
    destination_path = f"{path_volume}/csv/{csv_name}.csv"
    
    # Copy the file using Databricks File System utilities
    dbutils.fs.cp(
        source_path,
        destination_path
    )

# %% [markdown]
# ## Load CSV Data into DataFrames

# %%
# ====================================================================
# UTILITY FUNCTIONS FOR DATA TRANSFORMATION
# ====================================================================

from pyspark.sql.functions import monotonically_increasing_id

def addIdColumn(dataframe, id_column_name):
    """
    Add a unique ID column to a DataFrame as the first column.
    
    This function is essential for creating feature tables because:
    - Feature tables MUST have a primary key
    - The ID column ensures each row is uniquely identifiable
    - monotonically_increasing_id() generates distributed unique IDs
    
    Args:
        dataframe: Input Spark DataFrame
        id_column_name: Name for the new ID column (e.g., 'customer_feature_id')
    
    Returns:
        DataFrame with ID column as the first column
    
    Note:
        - IDs are guaranteed unique within a Spark session
        - IDs are monotonically increasing but may have gaps
        - The ID column is positioned first for better readability
    """
    # Store original column names
    columns = dataframe.columns
    
    # Add ID column 
    new_df = dataframe.withColumn(id_column_name, monotonically_increasing_id())

    # This improves readability and follows best practices for feature tables
    return new_df[[id_column_name] + columns]


def renameColumns(df):
    """
    Rename columns to be compatible with Unity Catalog Feature Engineering.
    
    Unity Catalog has naming restrictions:
    - Column names cannot contain spaces
    - Spaces must be replaced with underscores
    
    Args:
        df: Input Spark DataFrame with potentially non-compliant column names
    
    Returns:
        DataFrame with sanitized column names (spaces replaced by underscores)
    
    Example:
        Input columns: ['Customer Name', 'Order Date', 'Total Amount']
        Output columns: ['Customer_Name', 'Order_Date', 'Total_Amount']
    """
    renamed_df = df
    
    # Iterate through each column and replace spaces with underscores
    for column in df.columns:
        # withColumnRenamed() creates a new DataFrame with the renamed column
        renamed_df = renamed_df.withColumnRenamed(column, column.replace(' ', '_'))
    
    return renamed_df


def compute_customer_features(path_volume, table_name):
    """
    Load and transform CSV data into a feature-ready DataFrame.
    
    This function represents a feature engineering pipeline:
    1. Load raw CSV data from Unity Catalog volume
    2. Infer schema automatically from CSV structure
    3. Clean column names (remove spaces)
    4. Add primary key column for feature table
    
    Args:
        path_volume: path to the csv volume 
        table_name: Name of the CSV file 
    
    Returns:
        Spark DataFrame with:
        - Primary key column: {table_name}_feature_id
        - All original columns with sanitized names
        - Proper data types inferred from CSV
    
    Note:
        - inferSchema=True: Automatically detects column data types
        - header=True: First row contains column names
        - sep=",": Comma-separated values
    """
    # Load CSV file from Unity Catalog volume
    # spark.read.csv() creates a DataFrame from CSV data
    df = spark.read.csv(
        f"{path_volume}/csv/{table_name}.csv",
        header=True,        # First row contains column names
        inferSchema=True,   # Automatically detect data types (int, string, date, etc.)
        sep=","             # Comma delimiter (standard CSV)
    )
    
    # Transform the DataFrame for feature table compatibility
    # Step 1: Rename columns to replace spaces with underscores
    renamed_df = renameColumns(df)
    
    # Step 2: Add primary key column as the first column
    # Primary key format: {table_name}_feature_id
    # Example: 'customers_feature_id', 'orders_feature_id'
    return addIdColumn(renamed_df, f'{table_name}_feature_id')

# %% [markdown]
# ## Create Feature Tables in Unity Catalog

# %%
from databricks.feature_engineering import FeatureEngineeringClient
# Initialize the Feature Engineering Client
fe = FeatureEngineeringClient()


# ====================================================================
# MAIN LOOP: CREATE FEATURE TABLE FOR EACH CSV FILE
# ====================================================================

# Process each CSV file and create corresponding feature table
for csv_name in l_csv_names:
    print(f"\n{'='*10}")
    print(f"Processing table: {csv_name}")

    # Step 1: Load and transform CSV data into feature DataFrame
    features_df = compute_customer_features(path_volume=path_volume, table_name=csv_name)
    
    # Step 2: Create feature table in Unity Catalog
    feature_table = fe.create_table(
        name=f'{catalog}.{schema}.{csv_name}_feature',     # Full table name: catalog.schema.table_name_feature
        primary_keys=f'{csv_name}_feature_id',       # Primary key column (must be unique)
        df=features_df,                               # DataFrame containing the feature data
        schema=features_df.schema,                    # Schema inferred from DataFrame
        description=f'{csv_name} features'            # Human-readable description for documentation
    )
    
    # Step 3: Log the schema for verification and documentation
    print(f"\n✓ Created feature table: {catalog}.{schema}.{csv_name}_feature")
    print(f"\nTable schema:")
    print(f"{features_df.schema}")
# Out:
# ==========
# Processing table: customers
# 2026/08/30 03:44:20 INFO databricks.ml_features._compute_client._compute_client: Setting columns ['customers_feature_id'] of table 'demo.demo.customers_feature' to NOT NULL.
# 2026/08/30 03:44:21 INFO databricks.ml_features._compute_client._compute_client: Setting Primary Keys constraint ['customers_feature_id'] on table 'demo.demo.customers_feature'.
# 2026/08/30 03:44:28 INFO databricks.ml_features._compute_client._compute_client: Created feature table 'demo.demo.customers_feature'.
# ✓ Created feature table: demo.demo.customers_feature
#
# Table schema:
# StructType([StructField('customers_feature_id', LongType(), False), StructField('<!DOCTYPE_html>', StringType(), True)])
#
# ==========
# Processing table: orders
# 2026/08/30 03:44:36 INFO databricks.ml_features._compute_client._compute_client: Setting columns ['orders_feature_id'] of table 'demo.demo.orders_feature' to NOT NULL.
# 2026/08/30 03:44:37 INFO databricks.ml_features._compute_client._compute_client: Setting Primary Keys constraint ['orders_feature_id'] on table 'demo.demo.orders_feature'.
# 2026/08/30 03:44:42 INFO databricks.ml_features._compute_client._compute_client: Created feature table 'demo.demo.orders_feature'.
# ✓ Created feature table: demo.demo.orders_feature
#
# Table schema:
# StructType([StructField('orders_feature_id', LongType(), False), StructField('<!DOCTYPE_html>', StringType(), True)])
#
# ==========
# Processing table: order_items
# 2026/08/30 03:44:49 INFO databricks.ml_features._compute_client._compute_client: Setting columns ['order_items_feature_id'] of table 'demo.demo.order_items_feature' to NOT NULL.
# 2026/08/30 03:44:51 INFO databricks.ml_features._compute_client._compute_client: Setting Primary Keys constraint ['order_items_feature_id'] on table 'demo.demo.order_items_feature'.
# 2026/08/30 03:44:56 INFO databricks.ml_features._compute_client._compute_client: Created feature table 'demo.demo.order_items_feature'.
# ✓ Created feature table: demo.demo.order_items_feature
#
# Table schema:
# StructType([StructField('order_items_feature_id', LongType(), False), StructField('<!DOCTYPE_html>', StringType(), True)])
#
# ==========
# Processing table: products
# 2026/08/30 03:45:03 INFO databricks.ml_features._compute_client._compute_client: Setting columns ['products_feature_id'] of table 'demo.demo.products_feature' to NOT NULL.
# 2026/08/30 03:45:04 INFO databricks.ml_features._compute_client._compute_client: Setting Primary Keys constraint ['products_feature_id'] on table 'demo.demo.products_feature'.
# 2026/08/30 03:45:09 INFO databricks.ml_features._compute_client._compute_client: Created feature table 'demo.demo.products_feature'.
# ✓ Created feature table: demo.demo.products_feature
#
# Table schema:
# StructType([StructField('products_feature_id', LongType(), False), StructField('<!DOCTYPE_html>', StringType(), True)])
#
# ==========
# Processing table: shipping_zones
# 2026/08/30 03:45:16 INFO databricks.ml_features._compute_client._compute_client: Setting columns ['shipping_zones_feature_id'] of table 'demo.demo.shipping_zones_feature' to NOT NULL.
# 2026/08/30 03:45:17 INFO databricks.ml_features._compute_client._compute_client: Setting Primary Keys constraint ['shipping_zones_feature_id'] on table 'demo.demo.shipping_zones_feature'.
# 2026/08/30 03:45:22 INFO databricks.ml_features._compute_client._compute_client: Created feature table 'demo.demo.shipping_zones_feature'.
# ✓ Created feature table: demo.demo.shipping_zones_feature
#
# Table schema:
# StructType([StructField('shipping_zones_feature_id', LongType(), False), StructField('<!DOCTYPE_html>', StringType(), True)])
